# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelmorandini/am-t4-s1a2026/blob/main/aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução a Python

# %%
a=2
b=3
print('A soma é: ',a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print('A multiplicação é: ',c*d)
# Out:
# A multiplicação é:  20
